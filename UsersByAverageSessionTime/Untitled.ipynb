# %%
# Import your libraries
import pandas as pd
import numpy as np
import os

# %%
os.chdir('Average_Salaries')
path = os.getcwd()
print(path)
# Out:
# C:\Users\msold\StrataScratch\Average_Salaries

# %%
df = pd.read_csv('employee.csv')
df.head()
# Out:
#    id first_name last_name  age sex employee_title  department  salary  \
# 0   5        Max    George   26   M          Sales       Sales    1300
# 1  13      Katty      Bond   56   F        Manager  Management  150000
# 2  11    Richerd      Gear   57   M        Manager  Management  250000
# 3  10   Jennifer      Dion   34   F          Sales       Sales    1000
# 4  19     George       Joe   50   M        Manager  Management  100000
#
#    target  bonus                 email        city               address  \
# 0     200    150       Max@company.com  California  2638 Richards Avenue
# 1       0    300     Katty@company.com     Arizona                   NaN
# 2       0    300   Richerd@company.com     Alabama                   NaN
# 3     200    150  Jennifer@company.com     Alabama                   NaN
# 4       0    300    George@company.com     Florida     1003 Wyatt Street
#
#    manager_id
# 0           1
# 1           1
# 2           1
# 3          13
# 4           1

# %%
name_group = ['first_name','last_name']
target_bonus = ['target','bonus']

# %%
df[name_group + target_bonus + ['salary']].head()
# Out:
#   first_name last_name  target  bonus  salary
# 0        Max    George     200    150    1300
# 1      Katty      Bond       0    300  150000
# 2    Richerd      Gear       0    300  250000
# 3   Jennifer      Dion     200    150    1000
# 4     George       Joe       0    300  100000

# %%
df[name_group].head()
# Out:
#   first_name last_name
# 0        Max    George
# 1      Katty      Bond
# 2    Richerd      Gear
# 3   Jennifer      Dion
# 4     George       Joe

# %%
df[name_group + ['employee_title']].head()
# Out:
#   first_name last_name employee_title
# 0        Max    George          Sales
# 1      Katty      Bond        Manager
# 2    Richerd      Gear        Manager
# 3   Jennifer      Dion          Sales
# 4     George       Joe        Manager

# %%
df[name_group + ['age', 'employee_title']].head()
# Out:
#   first_name last_name  age employee_title
# 0        Max    George   26          Sales
# 1      Katty      Bond   56        Manager
# 2    Richerd      Gear   57        Manager
# 3   Jennifer      Dion   34          Sales
# 4     George       Joe   50        Manager
