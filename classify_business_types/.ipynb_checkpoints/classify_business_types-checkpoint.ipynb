# %% [markdown]
# ### Classify Business Type

# %% [markdown]
# Classify each business as either a restaurant, cafe, school, or other. A restaurant should have the word 'restaurant' in the business name. For cafes, either 'cafe', 'café', or 'coffee' can be in the business name. 'School' should be in the business name for schools. All other businesses should be classified as 'other'. Output the business name and the calculated classification.

# %%
# Import your libraries
import pandas as pd

# %%
# set display options
pd.options.display.max_columns = 20
pd.options.display.max_rows = 20
pd.options.display.max_colwidth = 80

# %%
#sf_restaurant_health_violations = pd.read_clipboard()
#sf_restaurant_health_violations.to_csv('sf_restaurant_health_violations.csv',index=False)
sf_restaurant_health_violations = pd.read_csv('sf_restaurant_health_violations.csv')
sf_restaurant_health_violations.head()
# Out:
#    business_id                   business_name   business_address  \
# 0         5800     John Chin Elementary School    350 Broadway St
# 1        64236       Sutter Pub and Restaurant      700 Sutter St
# 2         1991                SRI THAI CUISINE   4621 LINCOLN Way
# 3         3816  Washington Bakery & Restaurant  733 Washington St
# 4        39119             Brothers Restaurant    4128 GEARY Blvd
#
#    business_city business_state  business_postal_code  business_latitude  \
# 0  San Francisco             CA               94133.0             37.798
# 1  San Francisco             CA               94102.0             37.789
# 2  San Francisco             CA               94122.0             37.764
# 3  San Francisco             CA               94108.0             37.795
# 4  San Francisco             CA               94118.0             37.781
#
#    business_longitude  \
# 0            -122.403
# 1            -122.412
# 2            -122.508
# 3            -122.406
# ...

# %%
# Create new business type column with default 'z'
sf_restaurant_health_violations['business_type'] = 'z'

# %%
# create df of only restaurants
restaurants = sf_restaurant_health_violations.loc[sf_restaurant_health_violations['business_name'].str.contains("restaurant", na=False, case=False)]
restaurants.head()
# Out:
#    business_id                   business_name    business_address  \
# 1        64236       Sutter Pub and Restaurant       700 Sutter St
# 3         3816  Washington Bakery & Restaurant   733 Washington St
# 4        39119             Brothers Restaurant     4128 GEARY Blvd
# 8        68872   Jiang Ling Cuisine Restaurant  2517 SAN BRUNO Ave
# 9        80242         Wing Lee BBQ Restaurant     501 Clement St.
#
#    business_city business_state  business_postal_code  business_latitude  \
# 1  San Francisco             CA               94102.0             37.789
# 3  San Francisco             CA               94108.0             37.795
# 4  San Francisco             CA               94118.0             37.781
# 8  San Francisco             CA               94134.0             37.730
# 9  San Francisco             CA               94118.0                NaN
#
#    business_longitude  \
# 1            -122.412
# 3            -122.406
# 4            -122.464
# 8            -122.405
# ...

# %%
# create df of only cafes
cafe = sf_restaurant_health_violations.loc[sf_restaurant_health_violations['business_name'].str.contains("cafe", na=False, case=False)]
café = sf_restaurant_health_violations.loc[sf_restaurant_health_violations['business_name'].str.contains("café", na=False, case=False)]
coffee = sf_restaurant_health_violations.loc[sf_restaurant_health_violations['business_name'].str.contains("coffee", na=False, case=False)]
cafes = pd.concat([cafe, café, coffee], axis=0)

# %%
cafes.head()
# Out:
#     business_id      business_name    business_address  business_city  \
# 16          509        Cafe Bakery     1365 Noriega St  San Francisco
# 22         4421         Crepe Cafe  Pier 39  Space D-3  San Francisco
# 24        86990  Allstars Cafe Inc      1500 Market St  San Francisco
# 41        36473        Maggie Cafe       848 Grant Ave  San Francisco
# 51        81886      Cafe Broadway     674 Broadway St  San Francisco
#
#    business_state  business_postal_code  business_latitude  \
# 16             CA               94122.0             37.754
# 22             CA               94133.0             37.808
# 24             CA               94102.0                NaN
# 41             CA               94108.0             37.795
# 51             CA               94133.0                NaN
#
#     business_longitude  \
# 16            -122.478
# 22            -122.410
# 24                 NaN
# 41            -122.406
# 51                 NaN
#
# ...

# %%
# Create dataframe of only schools
school = sf_restaurant_health_violations.loc[sf_restaurant_health_violations['business_name'].str.contains("school", na=False, case=False)]

# %%
# create business type columns for each df
restaurants['business_type'] = 'restaurant'
cafes['business_type'] = 'cafe'
school['business_type'] = 'school'
# Out:
# <ipython-input-33-55a7752181aa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurants['business_type'] = 'restaurant'
# <ipython-input-33-55a7752181aa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   school['business_type'] = 'school'

# %%
# concat all dataframes
final = pd.concat([sf_restaurant_health_violations, restaurants, cafes,school], axis=0)

# %%
# sort by business name the business type
final.sort_values(by=['business_name', 'business_type'], ascending=[True, True],inplace=True)

# %%
# drop duplicates on business name, this will drop any of the 'z' business tpyes if they are present witha  different value
final = final.drop_duplicates(subset=['business_name'])

# %%
# Rename business tpye 'z' to 'other'
final['business_type'] = final['business_type'].replace({'z': 'Other'})

# %%
# get only the columns requested
final[['business_name','business_type']]
# Out:
#                                       business_name business_type
# 266                      24 Hour Fitness Club, #273         Other
# 263                          24th and Folsom Eatery         Other
# 249                     7-Eleven, Store 2366-21389F         Other
# 98                    95117 Premium Commissary Room         Other
# 163                                      A La Turca         Other
# ..                                              ...           ...
# 9                           Wing Lee BBQ Restaurant    restaurant
# 132                                   Wing Lum Cafe          cafe
# 52                                YUMMA'S MED GRILL         Other
# 243  Yerba Buena Tea Co (formerly Tea Smiths of SF)         Other
# 106                                    Yummy Sticks         Other
#
# [266 rows x 2 columns]
